# %% [markdown]
# 1. 关于pandas库的使用：主要用来从文件读取数据、将数据转换为易操作的dataFrame

# %%
import pandas as pd

# 读取本地文件并将其转换为可操作的dataFrame
filename = 'water_data_EEBD6FE99C8B_tmp'
df_csv = pd.read_csv(filename + '.csv')

print(df_csv)
# Out:
#                时间          ut  dn    i  心率  低压   高压   前面积   后面积   RR  step  \
# 0      1663810484  1663833205  80  303  90  73  130     0     0  326  4637
# 1      1663810485  1663833205  80  304  90  73  130   953  3228  642  4637
# 2      1663810486  1663833205  80  304  90  73  130  1023  3407  642  4637
# 3      1663810487  1663833205  80  304  90  73  130  1274  4263  646  4637
# 4      1663810488  1663833205  80  304  90  73  130  1577  5328  646  4637
# ...           ...         ...  ..  ...  ..  ..  ...   ...   ...  ...   ...
# 19543  1663832079  1663833394  80  573  76  74  134  1978  6609  542  6137
# 19544  1663832080  1663833394  80  573  76  74  134  1976  6681  544  6137
# 19545  1663832081  1663833394  80  573  76  74  134  1840  6179  544  6137
# 19546  1663832082  1663833394  80  573  76  74  134  1851  6228  544  6137
# 19547  1663832083  1663833394  80  573  76  74  134  1867  6306  546  6137
#
#        acc_x  acc_z  acc_y
# 0      -4611   4729   4544
# 1      -4498   4579   4745
# 2      -4567   4874   4624
# 3      -1080   2204   7797
# 4      -1527    454   8911
# ...      ...    ...    ...
# 19543   5555   5039  -5907
# 19544   4247   4164   5718
# 19545   4629   4076   5315
# 19546   4601   4426   5303
# 19547   4848   4142   5247
#
# [19548 rows x 14 columns]

# %% [markdown]
# 2. dataFrame(这里具体就是df_csv变量)可操作性非常强，可以任意对其进行行或者列数据整理，如下是对 acc_x  acc_z  acc_y 三列进行求和并保存为了新的列 add_xyz

# %%
df_csv["add_xyz"] = df_csv["acc_x"] + df_csv["acc_z"] + df_csv["acc_y"]

print(df_csv)
# Out:
#                时间          ut  dn    i  心率  低压   高压   前面积   后面积   RR  step  \
# 0      1663810484  1663833205  80  303  90  73  130     0     0  326  4637
# 1      1663810485  1663833205  80  304  90  73  130   953  3228  642  4637
# 2      1663810486  1663833205  80  304  90  73  130  1023  3407  642  4637
# 3      1663810487  1663833205  80  304  90  73  130  1274  4263  646  4637
# 4      1663810488  1663833205  80  304  90  73  130  1577  5328  646  4637
# ...           ...         ...  ..  ...  ..  ..  ...   ...   ...  ...   ...
# 19543  1663832079  1663833394  80  573  76  74  134  1978  6609  542  6137
# 19544  1663832080  1663833394  80  573  76  74  134  1976  6681  544  6137
# 19545  1663832081  1663833394  80  573  76  74  134  1840  6179  544  6137
# 19546  1663832082  1663833394  80  573  76  74  134  1851  6228  544  6137
# 19547  1663832083  1663833394  80  573  76  74  134  1867  6306  546  6137
#
#        acc_x  acc_z  acc_y  add_xyz
# 0      -4611   4729   4544     4662
# 1      -4498   4579   4745     4826
# 2      -4567   4874   4624     4931
# 3      -1080   2204   7797     8921
# 4      -1527    454   8911     7838
# ...      ...    ...    ...      ...
# 19543   5555   5039  -5907     4687
# 19544   4247   4164   5718    14129
# 19545   4629   4076   5315    14020
# 19546   4601   4426   5303    14330
# 19547   4848   4142   5247    14237
#
# [19548 rows x 15 columns]

# %% [markdown]
# 3. 关于其它库的使用，如NumPy和SciPy，烦请参考 https://zhuanlan.zhihu.com/p/234935501
